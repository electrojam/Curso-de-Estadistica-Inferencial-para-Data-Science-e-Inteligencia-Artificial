# %% [markdown]
# <a href="https://colab.research.google.com/github/electrojam/Curso-de-Estadistica-Inferencial-para-Data-Science-e-Inteligencia-Artificial/blob/main/Funciones_de_muestreo_en_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import random
import io #vamos a importar base de datos externa

# %% [markdown]
# ### Leemos la base de datos a trabajar en nuestra ruta de origen

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-831f5f69-6e89-485a-ba00-9567bc93b38d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-831f5f69-6e89-485a-ba00-9567bc93b38d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
econdata = pd.read_csv(io.BytesIO(uploaded["Econdata.csv"]))

# %%
econdata.head()
# Out:
#    id                  geo_point_2d  \
# 0   0   19.424781053,-99.1327537959
# 1   1  19.4346139576,-99.1413808393
# 2   2  19.4340695945,-99.1306348409
# 3   3      19.42489472,-99.12073393
# 4   4      19.42358238,-99.12451093
#
#                                            geo_shape   clave_cat  \
# 0  {"type": "Polygon", "coordinates": [[[-99.1332...  307_130_11
# 1  {"type": "MultiPoint", "coordinates": [[-99.14...  002_008_01
# 2  {"type": "MultiPoint", "coordinates": [[-99.13...  006_002_12
# 3  {"type": "MultiPoint", "coordinates": [[-99.12...  323_102_06
# 4  {"type": "MultiPoint", "coordinates": [[-99.12...  323_115_12
#
#             delegacion perimetro     tipo  \
# 0           Cuauhtémoc         B  Mercado
# 1            Cuautémoc         A    Museo
# 2            Cuautémoc         A    Museo
# 3  Venustiano Carranza         B    Hotel
# 4  Venustiano Carranza         B    Hotel
#
#                                               nom_id
# ...

# %% [markdown]
# ### Funciones de muestreo:

# %% [markdown]
# #### 1) Muestreo aleaotrio simple:

# %%
#Seleccionamos una nuetra muestra de 8 resultados aleatorios
aleat_8 = econdata.sample(n=8)
aleat_8
# Out:
#       id                  geo_point_2d  \
# 195  195  19.4414840739,-99.1394736635
# 144  144      19.43846278,-99.14185407
# 62    62  19.4377973772,-99.1504216904
# 12    12      19.43990186,-99.14813347
# 95    95  19.4370305998,-99.1214093113
# 205  205   19.435760727,-99.1309926143
# 15    15       19.42413788,-99.1324515
# 58    58  19.4244380424,-99.1306732022
#
#                                              geo_shape   clave_cat  \
# 195  {"type": "MultiPoint", "coordinates": [[-99.13...  004_050_13
# 144  {"type": "MultiPoint", "coordinates": [[-99.14...  003_097_17
# 62   {"type": "MultiPoint", "coordinates": [[-99.15...  011_034_16
# 12   {"type": "MultiPoint", "coordinates": [[-99.14...  003_079_16
# 95   {"type": "MultiPoint", "coordinates": [[-99.12...  318_114_01
# 205  {"type": "MultiPoint", "coordinates": [[-99.13...  005_129_16
# 15   {"type": "MultiPoint", "coordinates": [[-99.13...  307_153_11
# 58   {"type": "MultiPoint", "coordinates": [[-99.13...  307_124_19
#
# ...

# %%
#Seleccionamos otra nuetra muestra de 8 resultados aleatorios

aleat_8_2 = econdata.sample(n=8)
aleat_8_2
# Out:
#       id                  geo_point_2d  \
# 49    49  19.4264953358,-99.1248854383
# 213  213   19.432385153,-99.1274363518
# 123  123  19.4378770032,-99.1358867181
# 47    47     19.439101835,-99.13175662
# 210  210      19.43082385,-99.12366058
# 88    88  19.4324763822,-99.1373385944
# 225  225      19.43094655,-99.12455418
# 56    56  19.4452114301,-99.1425281852
#
#                                              geo_shape   clave_cat  \
# 49   {"type": "Polygon", "coordinates": [[[-99.1252...  323_139_01
# 213  {"type": "MultiPoint", "coordinates": [[-99.12...  006_018_09
# 123  {"type": "MultiPoint", "coordinates": [[-99.13...  004_086_36
# 47   {"type": "MultiPoint", "coordinates": [[-99.13...  004_081_31
# 210  {"type": "MultiPoint", "coordinates": [[-99.12...  323_029_08
# 88   {"type": "MultiPoint", "coordinates": [[-99.13...  001_022_08
# 225  {"type": "MultiPoint", "coordinates": [[-99.12...  323_027_04
# 56   {"type": "MultiPoint", "coordinates": [[-99.14...  003_043_01
#
# ...

# %%
#Seleccionamos una muestra de una fracción (25%) de la base de datos
prop_25 = econdata.sample(frac = 0.25)
prop_25.head()
# Out:
#       id                  geo_point_2d  \
# 204  204  19.4260286762,-99.1249971994
# 133  133  19.4388860834,-99.1250947991
# 188  188  19.4281241134,-99.1460742157
# 185  185    19.42697144,-99.1415371446
# 53    53  19.4419740424,-99.1401449131
#
#                                              geo_shape   clave_cat  \
# 204  {"type": "Polygon", "coordinates": [[[-99.1253...  323_138_01
# 133  {"type": "MultiPoint", "coordinates": [[-99.12...  005_099_14
# 188  {"type": "MultiPoint", "coordinates": [[-99.14...  002_067_08
# 185  {"type": "MultiPoint", "coordinates": [[-99.14...  001_065_14
# 53   {"type": "MultiPoint", "coordinates": [[-99.14...  003_069_16
#
#               delegacion perimetro     tipo      nom_id
# 204  Venustiano Carranza         B  Mercado    Florería
# 133            Cuautémoc         B    Hotel     Venecia
# 188            Cuautémoc         B    Hotel    Manolo 1
# 185            Cuautémoc         A    Hotel    Virreyes
# ...

# %% [markdown]
# ### Muestreo sistemático:

# %%
def systematic_sampling(econdata, step):
  indexes = np.arange(0, len(econdata), step=step) #recorre rango desde 0 hasta len del df econdata, step función de intervalos, lo definiremos
  systematic_sample = econdata.iloc[indexes]  #función se va a definir por lo lcalización donde esté econdata, y se define por los indices
  return systematic_sample

systematic_sample = systematic_sampling(econdata, 3)  #elige cada 3 observaciones (filas) del df
systematic_sample
# Out:
#       id                  geo_point_2d  \
# 0      0   19.424781053,-99.1327537959
# 3      3      19.42489472,-99.12073393
# 6      6      19.43553422,-99.12324801
# 9      9  19.4407152937,-99.1498060057
# 12    12      19.43990186,-99.14813347
# ..   ...                           ...
# 216  216  19.4247697438,-99.1249707246
# 219  219  19.4234096295,-99.1438351156
# 222  222   19.4397905042,-99.134628735
# 225  225      19.43094655,-99.12455418
# 228  228  19.4406567734,-99.1394531646
#
#                                              geo_shape   clave_cat  \
# 0    {"type": "Polygon", "coordinates": [[[-99.1332...  307_130_11
# 3    {"type": "MultiPoint", "coordinates": [[-99.12...  323_102_06
# 6    {"type": "MultiPoint", "coordinates": [[-99.12...  318_116_11
# 9    {"type": "MultiPoint", "coordinates": [[-99.14...  012_146_22
# 12   {"type": "MultiPoint", "coordinates": [[-99.14...  003_079_16
# ..                                                 ...         ...
# ...
